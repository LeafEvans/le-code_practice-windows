# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
x = np.arange(-10, 10, 0.0001)
y = np.sin(x) + np.cos(x)
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
a = [1, 2, 3]
myvar = pd.Series(a)
myvar[1]
# Out:
# 2

# %%
a = ['Google', 'Microsoft', 'Wiki']

myvar = pd.Series(a, index=['x', 'y', 'z'])

myvar
# Out:
# x       Google
# y    Microsoft
# z         Wiki
# dtype: object

# %%
myvar['x']
# Out:
# 'Google'

# %%
sites = {1: 'Google', 2: 'Wiki', 3: 'Microsoft'}

myvar = pd.Series(sites)
myvar
# Out:
# 1       Google
# 2         Wiki
# 3    Microsoft
# dtype: object

# %%
myvar = pd.Series(sites, index=[1, 3])

myvar
# Out:
# 1       Google
# 3    Microsoft
# dtype: object

# %%
s = pd.Series(np.array([1, 2, 3, 4]))

s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
s = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])

value = s.iloc[2]

s.iloc[1:3]
# Out:
# b    2
# c    3
# dtype: int64

# %%
for index, value in s.items():
    print(f"Index: {index}, Value: {value}")
# Out:
# Index: a, Value: 1
# Index: b, Value: 2
# Index: c, Value: 3
# Index: d, Value: 4

# %%
s['a':'c']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s['e'] = 5 
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
del s['a']
s
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
s_dropped = s.drop(['b', 'c'])
s_dropped
# Out:
# d    4
# dtype: int64

# %%
s *= 2 
s
# Out:
# b    4
# c    6
# d    8
# dtype: int64

# %%
filter_series = s[s > 5]
filter_series
# Out:
# c    6
# d    8
# dtype: int64

# %%
result = np.sqrt(s)
result
# Out:
# b    2.000000
# c    2.449490
# d    2.828427
# dtype: float64

# %%
result = s.mean()
result
# Out:
# 6.0

# %%
s > 5
# Out:
# b    False
# c     True
# d     True
# dtype: bool
